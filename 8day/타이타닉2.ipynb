# %% [markdown]
# ### 전처리

# %%
import pandas as pd

# %%
df = pd.read_csv('./data/06_(문제)타이타닉_분류_데이터셋.csv')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df = df.drop(['deck'], axis=1)
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
df = df.drop(['who'], axis=1)
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#      adult_male  embark_town alive  alone
# ...

# %%
df = df.dropna(subset=['age'])
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#      adult_male  embark_town alive  alone
# ...

# %%
df = df.reset_index(drop=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 714 entries, 0 to 713
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     714 non-null    int64
#  1   pclass       714 non-null    int64
#  2   sex          714 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        714 non-null    int64
#  5   parch        714 non-null    int64
#  6   fare         714 non-null    float64
#  7   embarked     712 non-null    object
#  8   class        714 non-null    object
#  9   adult_male   714 non-null    bool
#  10  embark_town  712 non-null    object
#  11  alive        714 non-null    object
#  12  alone        714 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(5)
# memory usage: 62.9+ KB

# %%
age_list = []

for i in range(0, len(df['age'])):
    if df['age'][i] >= 0 and df['age'][i] <10:
        age_list.append('0')
    elif df['age'][i] >= 10 and df['age'][i] <20:
        age_list.append('1')
    elif df['age'][i] >= 20 and df['age'][i] <30:
        age_list.append('2')
    elif df['age'][i] >= 30 and df['age'][i] <40:
        age_list.append('3')
    elif df['age'][i] >= 40 and df['age'][i] <50:
        age_list.append('4')
    elif df['age'][i] >= 50 and df['age'][i] <60:
        age_list.append('5')
    elif df['age'][i] >= 60 and df['age'][i] <70:
        age_list.append('6')
    elif df['age'][i] >= 70 and df['age'][i] <80:
        age_list.append('7')
    elif df['age'][i] >= 80 and df['age'][i] <90:
        age_list.append('8')
    elif df['age'][i] >= 90 and df['age'][i] <100:
        age_list.append('9')
    else:
        print('ok')

# %%
df['연령대'] = age_list
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 709         0       3  female  39.0      0      5  29.1250        Q   Third
# 710         0       2    male  27.0      0      0  13.0000        S  Second
# 711         1       1  female  19.0      0      0  30.0000        S   First
# 712         1       1    male  26.0      0      0  30.0000        C   First
# 713         0       3    male  32.0      0      0   7.7500        Q   Third
#
#      adult_male  embark_town alive  alone 연령대
# ...

# %%
sex_list = []
for i in range(0,len(df['sex'])):
    if df['sex'][i] == 'male' :
        sex_list.append('0')
    else :
        sex_list.append('1')
        
df['성별'] = sex_list
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 709         0       3  female  39.0      0      5  29.1250        Q   Third
# 710         0       2    male  27.0      0      0  13.0000        S  Second
# 711         1       1  female  19.0      0      0  30.0000        S   First
# 712         1       1    male  26.0      0      0  30.0000        C   First
# 713         0       3    male  32.0      0      0   7.7500        Q   Third
#
#      adult_male  embark_town alive  alone 연령대 성별
# ...

# %%
df_total = df.dropna(subset=['embarked'])
df_total = df_total.reset_index(drop=True)
df_total
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 707         0       3  female  39.0      0      5  29.1250        Q   Third
# 708         0       2    male  27.0      0      0  13.0000        S  Second
# 709         1       1  female  19.0      0      0  30.0000        S   First
# 710         1       1    male  26.0      0      0  30.0000        C   First
# 711         0       3    male  32.0      0      0   7.7500        Q   Third
#
#      adult_male  embark_town alive  alone 연령대 성별
# ...

# %%
df_total.to_csv('./data/titanic.csv')

# %%
data = df_total[['pclass','연령대','성별','sibsp','parch','fare']].to_numpy()
target = df_total['survived'].to_numpy()

from sklearn.model_selection import train_test_split

train_input, test_input, train_target, test_target = train_test_split(data, target, random_state=42)

train_input.shape
test_input.shape
# Out:
# (178, 6)

# %%
### k-최근접이웃분류 모델로 테스트
from sklearn.neighbors import KNeighborsClassifier

kn =KNeighborsClassifier()

kn.n_neighbors=3
kn.fit(train_input, train_target)
print(kn.score(train_input, train_target))
print(kn.score(test_input, test_target))
# Out:
# 0.8614232209737828
# 0.7303370786516854
# C:\Users\admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()

lr.fit(train_input, train_target)

print(lr.score(train_input, train_target))
print(lr.score(test_input, test_target))
# Out:
# 0.799625468164794
# 0.7865168539325843

# %%
from sklearn.linear_model import SGDClassifier

# 클래스(모델) 생성
sc = SGDClassifier(loss='log',max_iter=10, random_state=42)
sc.fit(train_input, train_target)

print(sc.score(train_input, train_target))
print(sc.score(test_input, test_target))
# Out:
# 0.6947565543071161
# 0.651685393258427
# C:\Users\admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:173: FutureWarning: The loss 'log' was deprecated in v1.1 and will be removed in version 1.3. Use `loss='log_loss'` which is equivalent.
#   warnings.warn(
# C:\Users\admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(

# %%
# 에포크 반복학습
import numpy as np

sc = SGDClassifier(loss = 'log', random_state=42)

train_score = []
test_score = []

# 범주 고유값
classes = np.unique(train_target)

# 반복을 300회 이상으로 테스트하여 정확도를 리스트에 저장
for _ in range(0, 300):
    sc.partial_fit(train_input,  train_target, classes = classes)
    
    train_score.append(sc.score(train_input, train_target))
    test_score.append(sc.score(test_input, test_target))
# Out:
# C:\Users\admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:173: FutureWarning: The loss 'log' was deprecated in v1.1 and will be removed in version 1.3. Use `loss='log_loss'` which is equivalent.
#   warnings.warn(
# C:\Users\admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:173: FutureWarning: The loss 'log' was deprecated in v1.1 and will be removed in version 1.3. Use `loss='log_loss'` which is equivalent.
#   warnings.warn(
# C:\Users\admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:173: FutureWarning: The loss 'log' was deprecated in v1.1 and will be removed in version 1.3. Use `loss='log_loss'` which is equivalent.
#   warnings.warn(
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(train_score, label='train_score')
plt.plot(test_score, label='test_score')
plt.legend()
plt.show()

# %%
### 최적의 에포크값 이용해 처음부터 훈련 시작
### 사용 클래스(모델) : SGDClassifier

from sklearn.linear_model import SGDClassifier

# 클래스(모델) 생성
# tol = None : 스스로 훈련이 끝나도 멈추지 말고 지정값까지 돌게 함
sc = SGDClassifier(loss='log',max_iter=160, tol=None, random_state=42)
sc.fit(train_input, train_target)
print(sc.score(train_input, train_target))
print(sc.score(test_input, test_target))
# Out:
# 0.7808988764044944
# 0.702247191011236
# C:\Users\admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:173: FutureWarning: The loss 'log' was deprecated in v1.1 and will be removed in version 1.3. Use `loss='log_loss'` which is equivalent.
#   warnings.warn(

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()


lr.fit(train_input, train_target)

print(lr.score(train_input, train_target))
print(lr.score(test_input, test_target))
# Out:
# 0.799625468164794
# 0.7865168539325843

# %%
# from sklearn.preprocessing import StandardScaler

# ss = StandardScaler()
# ss.fit(train_input, train_target)
lr.fit(train_input, train_target)


pre_data = df_total[['pclass','연령대','성별','sibsp','parch','fare']].to_numpy()
# class_pred = lr.(pre_data)

result_predict = lr.predict(pre_data)
df_total['생존예측'] = result_predict
df_total.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       1    male  54.0      0      0  51.8625        S   First
# 6         0       3    male   2.0      3      1  21.0750        S   Third
# 7         1       3  female  27.0      0      2  11.1333        S   Third
# 8         1       2  female  14.0      1      0  30.0708        C  Second
# 9         1       3  female   4.0      1      1  16.7000        S   Third
#
#    adult_male  embark_town alive  alone 연령대 성별  생존예측
# 0        True  Southampton    no  False   2  0     0
# ...

# %%
o = len(df_total[(df_total['survived'] == df_total['생존예측'])])
x = len(df_total[(df_total['survived'] != df_total['생존예측'])])

sum = len(df_total)

# 정답/오답률
import numpy as np

o_p = np.round(o / sum * 100, 2)
x_p = np.round(x / sum * 100, 2)

print(f'총 갯수 [{sum}] 중 정답 개수[{o}], 오답 개수[{x}]')
print('정답률 =', o_p,'%, 오답률 = ',x_p,'%')
# Out:
# 총 갯수 [712] 중 정답 개수[567], 오답 개수[145]
# 정답률 = 79.63 %, 오답률 =  20.37 %

# %%
import seaborn as sns

# %%
sns.barplot(x='sex',y='survived',hue='class', data=df_total)

# (해석)
# first 객실 탑승 여성의 생존율이 가장 높고
# 남성보다 여성의 생존율이 객실별로 모두 높음
# 성별 관계없이 객실이 좋을 수록 생존율 높음
# Out:
# <AxesSubplot:xlabel='sex', ylabel='survived'>

# %%
# 범주형 : 범주형 데이터 사용
ti = df_total.pivot_table(values='survived',
                            index='alive',
                            columns = 'sex',
                            aggfunc = 'count')
ti
# Out:
# sex    female  male
# alive
# no         64   360
# yes       195    93

# %%
sns.heatmap(ti, annot=True, fmt='.0f', cmap=sns.light_palette('gray', as_cmap=True))
# Out:
# <AxesSubplot:xlabel='sex', ylabel='alive'>

# %%
# 범주형 : 범주형 데이터 사용
ti2 = df_total.pivot_table(values='survived',
                            index='alive',
                            columns = 'class',
                            aggfunc = 'count')
sns.heatmap(ti2, annot=True, fmt='.0f', cmap=sns.light_palette('gray', as_cmap=True))
# Out:
# <AxesSubplot:xlabel='class', ylabel='alive'>

# %%
# 범주형 : 범주형 데이터 사용
plt.rc('font', family = 'Malgun Gothic', size = 10)
ti3 = df_total.pivot_table(values='survived',
                            index='alive',
                            columns = '연령대',
                            aggfunc = 'count')

sns.heatmap(ti3, annot=True, fmt='.0f', cmap=sns.light_palette('gray', as_cmap=True))
# Out:
# <AxesSubplot:xlabel='연령대', ylabel='alive'>
