# %% [markdown]
# ### API

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import openpyxl

# %%
### 시.도별   0.5v
import requests

apikey = '6nUHTYGhlDvu63VljyaHdyJ8xsQpwx4eLrr8xqFhG8j5Dniin7EIJEE6q5KoHyMi81fGbnZngJGJFraGewkAzA%3D%3D'

pageNo = 1
numOfRows = 10
startCreateDt=20200410
endCreateDt=20200410



api='http://openapi.data.go.kr/openapi/service/rest/Covid19/getCovid19SidoInfStateJson?serviceKey={apikey} &pageNo={no}&numOfRows={row}&startCreateDt={scdt}&endCreateDt={ecdt}'


url = api.format(apikey=apikey,
                no=pageNo,
                row=numOfRows,
                scdt=startCreateDt,
                ecdt=endCreateDt)
# requses =요청, response =응답
response = requests.get(url)
print(response.text)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>99</resultCode><resultMsg>SERVICE KEY IS NOT REGISTERED ERROR.</resultMsg></header></response>

# %%
import requests

apikey = 'PJxL%2BXY%2F3jCY4HSnB6mvwYVVe%2FRjjeO2Mh0HsQUsNo%2FrFTh3m87PBCzUhIEDInkArvhb5jRrWxzoq5JWW97Eow%3D%3D'

no = 1
row = 10
start = 20200101
end = 20220812


api = "http://openapi.data.go.kr/openapi/service/rest/Covid19/getCovid19InfStateJson?serviceKey={key}&pageNo={no}&numOfRows={row}&startCreateDt={start}0&endCreateDt={end}"

url = api.format(key = apikey,
                 no = no,
                 row = row,
                 start = start,
                 end = end)

response = requests.get(url)

# %%
re = response.text
soup = BeautifulSoup(re, 'html.parser')
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\bs4\builder\__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(

# %%
createdt_nmlist = soup.find_all('createdt')
deathcnt_nmlist = soup.find_all('deathcnt')
decidecnt_nmlist = soup.find_all('decidecnt')
seq_nmlist = soup.find_all('seq')
statedt_nmlist = soup.find_all('statedt')
statetime_nmlist = soup.find_all('statetime')
updatedt_nmlist = soup.find_all('updatedt')

createdt_txt_list = []
deathcnt_txt_list = []
decidecnt_txt_list = []
seq_txt_list = []
statedt_txt_list = []
statetime_txt_list = []
updatedt_txt_list = []

for i in range(0, len(updatedt_nmlist), 1) :
    createdt_txt_list.append(createdt_nmlist[i].text)
    deathcnt_txt_list.append(deathcnt_nmlist[i].text)
    decidecnt_txt_list.append(decidecnt_nmlist[i].text)
    seq_txt_list.append(seq_nmlist[i].text)
    statedt_txt_list.append(statedt_nmlist[i].text)
    statetime_txt_list.append(statetime_nmlist[i].text)
    updatedt_txt_list.append(updatedt_nmlist[i].text)
    
df_temp = pd.DataFrame({
                        '등록일시분초' : createdt_txt_list,
                        '사망자수' : deathcnt_txt_list,
                        '확진자수' : decidecnt_txt_list,
                        '게시글번호' : seq_txt_list,
                        '기준일' : statedt_txt_list,
                        '기준시간' : statetime_txt_list,
                        '수정일시분초' : updatedt_txt_list})

df_temp
# Out:
#                       등록일시분초   사망자수      확진자수 게시글번호       기준일   기준시간  \
# 0    2022-08-12 08:40:20.037  25499  21111840   972  20220812  00:00
# 1    2022-08-11 09:10:29.411  25441  20983126   971  20220811  00:00
# 2    2022-08-10 09:21:32.068  25382  20845885   970  20220810  00:00
# 3    2022-08-09 09:06:13.288  25332  20694119   969  20220809  00:00
# 4    2022-08-08 09:03:33.354  25292  20544248   968  20220808  00:00
# ..                       ...    ...       ...   ...       ...    ...
# 927  2020-01-26 09:00:00.000      0         3     7  20200126  09:00
# 928  2020-01-25 00:00:00.000      0         2     6  20200125  00:00
# 929  2020-01-24 00:00:00.000      0         2     5  20200124  00:00
# 930  2020-01-23 09:00:00.000      0         1     4  20200123  09:00
# 931  2020-01-22 12:00:00.000      0         1     3  20200122  12:00
#
#                       수정일시분초
# 0                       null
# 1    2022-08-12 08:42:19.947
# 2    2022-08-12 08:42:34.587
# ...

# %%
### (연령별,성별감염)발생현황서비스_v0.3
import requests

apikey = '6nUHTYGhlDvu63VljyaHdyJ8xsQpwx4eLrr8xqFhG8j5Dniin7EIJEE6q5KoHyMi81fGbnZngJGJFraGewkAzA%3D%3D'

api ='http://openapi.data.go.kr/openapi/service/rest/Covid19/getCovid19GenAgeCaseInfJson?serviceKey={key}&pageNo=1&numOfRows=10&startCreateDt=20200310&endCreateDt=20200414'

url = api.format(key=apikey)

response = requests.get(url)

print(response.content)
# Out:
# b'<?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><confCase>4255</confCase><confCaseRate>40.28</confCaseRate><createDt>2020-04-14 09:00:00.000</createDt><criticalRate>2.73</criticalRate><death>116</death><deathRate>52.25</deathRate><gubun>\xeb\x82\xa8\xec\x84\xb1</gubun><seq>946</seq><updateDt>2021-10-07 14:17:35.398</updateDt></item><item><confCase>6309</confCase><confCaseRate>59.72</confCaseRate><createDt>2020-04-14 09:00:00.000</createDt><criticalRate>1.68</criticalRate><death>106</death><deathRate>47.75</deathRate><gubun>\xec\x97\xac\xec\x84\xb1</gubun><seq>945</seq><updateDt>2021-10-07 14:17:35.398</updateDt></item><item><confCase>477</confCase><confCaseRate>4.52</confCaseRate><createDt>2020-04-14 09:00:00.000</createDt><criticalRate>22.22</criticalRate><death>106</death><deathRate>47.75</deathRate><gubun>80 \xec\x9d\xb4\xec\x83\x81</gubun><seq>944</seq><updateDt
# ...

# %%
re = response.text
soup = BeautifulSoup(re,"html.parser")
confCase_list = soup.find_all('confcase')
confCaseRate_list = soup.find_all('confcaserate')
createDt_list = soup.find_all('createdt')
criticalRate_list = soup.find_all('criticalrate')
death_list = soup.find_all('death')
deathate_list = soup.find_all('deathrate')
gubun_list = soup.find_all('gubun')

#<태그시작> ~ </태그끝>
#0번째에 있는 text를 가져와 (의미있는 정보인지 확인)
#  


gubun_list[0].text
# Out:
# c:\Users\admin\anaconda3\lib\site-packages\bs4\builder\__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(
# '남성'

# %%
# for i in range(0, len(gubun),1):
#     print(gubun[i])
a = []    
b = []
c = []
d = []
e = []
f = []
g = []

df=pd.DataFrame()
for i in range(0, len(gubun_list),1):    

    a.append(confCase_list[i].text)
    b.append(confCaseRate_list[i].text)
    c.append(createDt_list[i].text)
    d.append(criticalRate_list[i].text)
    e.append(death_list[i].text)
    f.append(deathate_list[i].text)
    g.append(gubun_list[i].text)

df['확진자'] =pd.DataFrame(a)
df['확진률']= pd.DataFrame(b)
df['등록일시분초'] =pd.DataFrame(c)
df['치명률']= pd.DataFrame(d)
df['사망자'] =pd.DataFrame(e)
df['사망률'] =pd.DataFrame(f)
df['성별,연령별']=pd.DataFrame(g)

df
    # print('전화번호[',i,'] : ', telno_list[i].text)
# Out:
#       확진자    확진률                   등록일시분초    치명률  사망자    사망률 성별,연령별
# 0    4255  40.28  2020-04-14 09:00:00.000   2.73  116  52.25     남성
# 1    6309  59.72  2020-04-14 09:00:00.000   1.68  106  47.75     여성
# 2     477   4.52  2020-04-14 09:00:00.000  22.22  106  47.75  80 이상
# 3     700   6.63  2020-04-14 09:00:00.000   9.29   65  29.28  70-79
# 4    1338  12.67  2020-04-14 09:00:00.000   2.47   33  14.86  60-69
# ..    ...    ...                      ...    ...  ...    ...    ...
# 391  1031  13.72  2020-03-10 09:00:00.000   0.10    1   1.85  40-49
# 392   788  10.49  2020-03-10 09:00:00.000   0.13    1   1.85  30-39
# 393  2214  29.47  2020-03-10 09:00:00.000   0.00    0   0.00  20-29
# 394   393   5.23  2020-03-10 09:00:00.000   0.00    0   0.00  10-19
# 395    67   0.89  2020-03-10 09:00:00.000   0.00    0   0.00    0-9
#
# [396 rows x 7 columns]

# %%
df_temp.info()
df_temp

df_temp
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 932 entries, 0 to 931
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   등록일시분초   932 non-null    object
#  1   사망자수     932 non-null    object
#  2   확진자수     932 non-null    object
#  3   게시글번호    932 non-null    object
#  4   기준일      932 non-null    object
#  5   기준시간     932 non-null    object
#  6   수정일시분초   932 non-null    object
#  7   일일 사망자수  932 non-null    int64
# dtypes: int64(1), object(7)
# memory usage: 58.4+ KB
#                       등록일시분초   사망자수      확진자수 게시글번호       기준일   기준시간  \
# 0    2022-08-12 08:40:20.037  25499  21111840   972  20220812  00:00
# 1    2022-08-11 09:10:29.411  25441  20983126   971  20220811  00:00
# 2    2022-08-10 09:21:32.068  25382  20845885   970  20220810  00:00
# 3    2022-08-09 09:06:13.288  25332  20694119   969  20220809  00:00
# 4    2022-08-08 09:03:33.354  25292  20544248   968  20220808  00:00
# ...

# %%
# # df_temp.loc[0,'수정일시분초'] = '2022-08-12 08:42:04.502'
t =[]

for i in range(len(df_temp)):    
    if (len(df_temp)-1)==i:
        t.append(0)
        break    
    
    t.append(int(df_temp['사망자수'][i]) - int(df_temp['사망자수'][i+1]))
    
df_temp['일일 사망자수'] =t
df_temp

y =[]

for i in range(len(df_temp)):    
    if (len(df_temp)-1)==i:
        y.append(0)
        break    
    
    y.append(int(df_temp['확진자수'][i]) - int(df_temp['확진자수'][i+1]))
    
df_temp['일일 확진자수'] =y
df_temp

df_temp.loc[0,'수정일시분초'] = '2022-08-12 08:42:04.502'

df_temp
# Out:
#                       등록일시분초   사망자수      확진자수 게시글번호       기준일   기준시간  \
# 0    2022-08-12 08:40:20.037  25499  21111840   972  20220812  00:00
# 1    2022-08-11 09:10:29.411  25441  20983126   971  20220811  00:00
# 2    2022-08-10 09:21:32.068  25382  20845885   970  20220810  00:00
# 3    2022-08-09 09:06:13.288  25332  20694119   969  20220809  00:00
# 4    2022-08-08 09:03:33.354  25292  20544248   968  20220808  00:00
# ..                       ...    ...       ...   ...       ...    ...
# 927  2020-01-26 09:00:00.000      0         3     7  20200126  09:00
# 928  2020-01-25 00:00:00.000      0         2     6  20200125  00:00
# 929  2020-01-24 00:00:00.000      0         2     5  20200124  00:00
# 930  2020-01-23 09:00:00.000      0         1     4  20200123  09:00
# 931  2020-01-22 12:00:00.000      0         1     3  20200122  12:00
#
#                       수정일시분초  일일 사망자수  일일 확진자수
# 0    2022-08-12 08:42:04.502       58   128714
# ...
